# %% [markdown]
# ## expand_contractions(text)

# %%
contractions_mapping = {
    "ain't": ["am", "not"],
    "aren't": ["are", "not"],
    "can't": ["can", "not"],
    "can't've": ["cannot", "have"],
    "'cause": ["because"],
    "could've": ["could", "have"],
    "couldn't": ["could", "not"],
    "couldn't've": ["could", "not", "have"],
    "didn't": ["did", "not"],
    "doesn't": ["does", "not"],
    "don't": ["do", "not"],
    "hadn't": ["had", "not"],
    "hadn't've": ["had", "not", "have"],
    "hasn't": ["has", "not"],
    "haven't": ["have", "not"],
    "he'd": ["he", "would"],
    "he'd've": ["he", "would", "have"],
    "he'll": ["he", "will"],
    "he'll've": ["he", "will", "have"],
    "he's": ["he", "is"],
    "how'd": ["how", "did"],
    "how'd'y": ["how", "do", "you"],
    "how'll": ["how", "will"],
    "how's": ["how", "is"],
    "i'd": ["i", "would"],
    "i'd've": ["i", "would", "have"],
    "i'll": ["i", "will"],
    "i'll've": ["i", "will", "have"],
    "i'm": ["i", "am"],
    "i've": ["i", "have"],
    "isn't": ["is", "not"],
    "it'd": ["it", "would"],
    "it'd've": ["it", "would", "have"],
    "it'll": ["it", "will"],
    "it'll've": ["it", "will", "have"],
    "it's": ["it", "is"],
    "let's": ["let", "us"],
    "ma'am": ["madam"],
    "mayn't": ["may", "not"],
    "might've": ["might", "have"],
    "mightn't": ["might", "not"],
    "mightn't've": ["might", "not", "have"],
    "must've": ["must", "have"],
    "mustn't": ["must", "not"],
    "mustn't've": ["must", "not", "have"],
    "needn't": ["need", "not"],
    "needn't've": ["need", "not", "have"],
    "o'clock": ["of", "the", "clock"],
    "oughtn't": ["ought", "not"],
    "oughtn't've": ["ought", "not", "have"],
    "shan't": ["shall", "not"],
    "sha'n't": ["shall", "not"],
    "shan't've": ["shall", "not", "have"],
    "she'd": ["she", "would"],
    "she'd've": ["she", "would", "have"],
    "she'll": ["she", "will"],
    "she'll've": ["she", "will", "have"],
    "she's": ["she", "is"],
    "should_ve": ["should", "have"],
    "should've": ["should", "have"],
    "shouldn't": ["should", "not"],
    "shouldn't've": ["should", "not", ],
    "shouldn't_ve": ["should", "not", "have"],
    "so've": ["so", "have"],
    "so's": ["so", "is"],
    "that'd": ["that", "would"],
    "that'd've": ["that", "would", "have"],
    "that's": ["that", "is"],
    "there'd": ["there", "would"],
    "there'd've": ["there", "would", "have"],
    "there's": ["there", "is"],
    "they'd": ["they", "would"],
    "they'd've": ["they", "would", "have"],
    "they'll": ["they", "will"],
    "they'll've": ["they", "will", "have"],
    "they're": ["they", "are"],
    "they've": ["they", "have"],
    "to've": ["to", "have"],
    "wasn't": ["was", "not"],
    "we'd": ["we", "would"],
    "we'd've": ["we", "would", "have"],
    "we'll": ["we", "will"],
    "we'll've": ["we", "will", "have"],
    "we're": ["we", "are"],
    "we've": ["we", "have"],
    "weren't": ["were", "not"],
    "what'll": ["what", "will"],
    "what'll've": ["what", "will", "have"],
    "what're": ["what", "are"],
    "what's": ["what", "is"],
    "what've": ["what", "have"],
    "when's": ["when", "is"],
    "when've": ["when", "have"],
    "where'd": ["where", "did"],
    "where's": ["where", "is"],
    "where've": ["where", "have"],
    "who'll": ["who", "will"],
    "who'll've": ["who", "will", "have"],
    "who's": ["who", "is"],
    "who've": ["who", "have"],
    "why's": ["why", "is"],
    "why've": ["why", "have"],
    "will've": ["will", "have"],
    "won't": ["will", "not"],
    "won't've": ["will", "not", "have"],
    "would've": ["would", "have"],
    "wouldn't": ["would", "not"],
    "wouldn't've": ["would", "not", "have"],
    "y'all": ["you", "all"],
    "y'all'd": ["you", "all", "would"],
    "y'all'd've": ["you", "all", "would", "have"],
    "y'all're": ["you", "all", "are"],
    "y'all've": ["you", "all", "have"],
    "you'd": ["you", "would"],
    "you'd've": ["you", "would", "have"],
    "you'll": ["you", "will"],
    "you'll've": ["you", "will", "have"],
    "you're": ["you", "are"],
    "you've": ["you", "have"],
}
def expand_contractions(text):
    expanded_text = []

    words = text.split()

    for word in words:
        if word in contractions_mapping:
            expanded_text.extend(contractions_mapping[word])
        else:
            expanded_text.append(word)
    return " ".join(expanded_text)

# %% [markdown]
# ## remove_punctuations(text) with regix expression

# %%
import re
def remove_punctuations(text):
    pattern = r'[.,!?:;\-_()\[\]{}"\`~@#$%^&*=+|\\/<>‘]'
    return re.sub(pattern, '', text)

# %% [markdown]
# ## remove_stopwords(text)

# %%
stop_words = {
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your',
    'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her',
    'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs',
    'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those',
    'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
    'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if',
    'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with',
    'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',
    'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over',
    'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where',
    'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other',
    'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too',
    'very', 'can', 'will', 'just', 'don', 'should', 'now'
}
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    return " ".join(filtered_words)

# %% [markdown]
# ## Text_Processing(text)

# %%
def Text_Processing(text):
    text = text if isinstance(text, str) else str(text)
    processedText = text.lower()
    processedText = expand_contractions(processedText)
    processedText = remove_punctuations(processedText)
    processedText = remove_stopwords(processedText)
    return processedText

# %% [markdown]
# ## Porter2(Snowball)

# %%
class Porter2Stemmer:
    def __init__(self):
        self.vowels = "aeiouy"
        self.double_consonants = ["bb", "dd", "ff", "gg", "mm", "nn", "pp", "rr", "tt"]
        self.li_endings = "cdeghkmnrt"

        # Step 1a suffixes
        self.step1a_suffixes = [
            ("sses", "ss"),
            ("ied", "i"),
            ("ies", "i"),
            ("us", "us"),
            ("ss", "ss"),
            ("s", "")
        ]

        # Step 1b suffixes
        self.step1b_suffixes = [
            "eedly", "eed", "ingly", "edly", "ing", "ed"
        ]

        # Step 2 suffixes
        self.step2_suffixes = [
            ("ational", "ate"),
            ("tional", "tion"),
            ("enci", "ence"),
            ("anci", "ance"),
            ("abli", "able"),
            ("entli", "ent"),
            ("izer", "ize"),
            ("ization", "ize"),
            ("ation", "ate"),
            ("ator", "ate"),
            ("alism", "al"),
            ("aliti", "al"),
            ("alli", "al"),
            ("fulness", "ful"),
            ("ousli", "ous"),
            ("ousness", "ous"),
            ("iveness", "ive"),
            ("iviti", "ive"),
            ("biliti", "ble"),
            ("bli", "ble"),
            ("ogi", "og"),
            ("fulli", "ful"),
            ("lessli", "less"),
            ("li", "")
        ]

        # Step 3 suffixes
        self.step3_suffixes = [
            ("ational", "ate"),
            ("tional", "tion"),
            ("alize", "al"),
            ("icate", "ic"),
            ("itive", ""),
            ("ical", "ic"),
            ("ful", ""),
            ("ness", "")
        ]

        # Step 4 suffixes
        self.step4_suffixes = [
            "al", "ance", "ence", "er", "ic", "able", "ible", "ant", "ement",
            "ment", "ent", "ion", "ou", "ism", "ate", "iti", "ous", "ive", "ize"
        ]

        # Step 5 suffixes
        self.step5_suffixes = ["e", "l"]

    def is_vowel(self, word, i):
        """Check if character at position i is a vowel"""
        if i < 0 or i >= len(word):
            return False

        char = word[i].lower()
        if char in "aeiou":
            return True
        if char == 'y' and i > 0 and not self.is_vowel(word, i - 1):
            return True
        return False

    def get_measure(self, word):
        """Calculate the measure of a word (number of VC patterns)"""
        measure = 0
        i = 0
        word_len = len(word)

        # Skip initial consonants
        while i < word_len and not self.is_vowel(word, i):
            i += 1

        # Count VC patterns
        while i < word_len:
            # Skip vowels
            while i < word_len and self.is_vowel(word, i):
                i += 1
            if i >= word_len:
                break

            # Skip consonants
            while i < word_len and not self.is_vowel(word, i):
                i += 1
            measure += 1

        return measure

    def has_vowel(self, word):
        """Check if word contains a vowel"""
        for i in range(len(word)):
            if self.is_vowel(word, i):
                return True
        return False

    def ends_with_double_consonant(self, word):
        """Check if word ends with double consonant"""
        if len(word) >= 2:
            last_two = word[-2:].lower()
            return last_two in self.double_consonants
        return False

    def cvc_pattern(self, word):
        """Check if word ends with consonant-vowel-consonant pattern (with restrictions)"""
        if len(word) < 3:
            return False

        word_len = len(word)
        if (not self.is_vowel(word, word_len - 3) and
            self.is_vowel(word, word_len - 2) and
            not self.is_vowel(word, word_len - 1) and
            word[-1].lower() not in "wxy"):
            return True
        return False

    def find_r1_r2(self, word):
        """Find R1 and R2 regions"""
        word_lower = word.lower()

        # Special cases for R1
        if word_lower.startswith(("gener", "commun", "arsen")):
            r1_start = 5
        else:
            # Find first vowel followed by consonant
            r1_start = 0
            for i in range(len(word) - 1):
                if self.is_vowel(word, i) and not self.is_vowel(word, i + 1):
                    r1_start = i + 2
                    break
            else:
                r1_start = len(word)

        # R1 is the substring after the first vowel-consonant pair
        r1 = word[r1_start:] if r1_start < len(word) else ""

        # Find R2 within R1
        r2_start = r1_start
        for i in range(r1_start, len(word) - 1):
            if self.is_vowel(word, i) and not self.is_vowel(word, i + 1):
                r2_start = i + 2
                break
        else:
            r2_start = len(word)

        r2 = word[r2_start:] if r2_start < len(word) else ""

        return r1_start, r2_start, r1, r2

    def step0(self, word):
        """Step 0: Remove possessive suffixes"""
        if word.endswith("'s'"):
            return word[:-3]
        elif word.endswith("'s"):
            return word[:-2]
        elif word.endswith("'"):
            return word[:-1]
        return word

    def step1a(self, word):
        """Step 1a: Handle plurals and past participles"""
        for suffix, replacement in self.step1a_suffixes:
            if word.endswith(suffix):
                if suffix in ["ied", "ies"]:
                    if len(word) > 4:
                        return word[:-len(suffix)] + "i"
                    else:
                        return word[:-len(suffix)] + "ie"
                elif suffix == "s":
                    # Only remove 's' if preceded by vowel that's not u
                    if len(word) > 2:
                        preceding = word[-2]
                        if self.is_vowel(word, len(word) - 2) and preceding != 'u':
                            return word[:-1]
                    return word
                else:
                    return word[:-len(suffix)] + replacement
        return word

    def step1b(self, word):
        """Step 1b: Handle -ed, -edly, -ing, -ingly, -eed, -eedly"""
        r1_start, r2_start, r1, r2 = self.find_r1_r2(word)

        # Handle eedly and eed
        if word.endswith("eedly"):
            if r1.endswith("eedly"):
                return word[:-5] + "ee"
        elif word.endswith("eed"):
            if r1.endswith("eed"):
                return word[:-3] + "ee"

        # Handle other suffixes
        for suffix in ["ingly", "edly", "ing", "ed"]:
            if word.endswith(suffix):
                stem = word[:-len(suffix)]
                if self.has_vowel(stem):
                    # Post-process the stem
                    if stem.endswith(("at", "bl", "iz")):
                        return stem + "e"
                    elif self.ends_with_double_consonant(stem):
                        # Remove double consonant except for l, s, z
                        if stem[-1].lower() not in "lsz":
                            return stem[:-1]
                    elif (self.get_measure(stem) == 1 and self.cvc_pattern(stem)):
                        return stem + "e"
                    return stem

        return word

    def step1c(self, word):
        """Step 1c: Replace y or Y with i if preceded by consonant"""
        if len(word) > 2 and word[-1].lower() == 'y':
            if not self.is_vowel(word, len(word) - 2):
                return word[:-1] + 'i'
        return word

    def step2(self, word):
        """Step 2: Remove derivational suffixes"""
        r1_start, r2_start, r1, r2 = self.find_r1_r2(word)

        for suffix, replacement in self.step2_suffixes:
            if word.endswith(suffix):
                if suffix == "li" and len(word) > 2:
                    # Special case for li
                    if r1.endswith("li") and word[-3].lower() in self.li_endings:
                        return word[:-2]
                elif suffix == "ogi" and len(word) > 3:
                    # Special case for ogi
                    if r1.endswith("ogi") and word[-4].lower() == 'l':
                        return word[:-3] + "og"
                elif r1.endswith(suffix):
                    return word[:-len(suffix)] + replacement
                break

        return word

    def step3(self, word):
        """Step 3: Remove derivational suffixes"""
        r1_start, r2_start, r1, r2 = self.find_r1_r2(word)

        for suffix, replacement in self.step3_suffixes:
            if word.endswith(suffix):
                if suffix == "ative":
                    if r2.endswith("ative"):
                        return word[:-6]
                elif r1.endswith(suffix):
                    return word[:-len(suffix)] + replacement
                break

        return word

    def step4(self, word):
        """Step 4: Remove derivational suffixes"""
        r1_start, r2_start, r1, r2 = self.find_r1_r2(word)

        for suffix in self.step4_suffixes:
            if word.endswith(suffix):
                if suffix == "ion":
                    # Special case for ion
                    if (r2.endswith("ion") and len(word) > 3 and
                        word[-4].lower() in "st"):
                        return word[:-3]
                elif r2.endswith(suffix):
                    return word[:-len(suffix)]
                break

        return word

    def step5(self, word):
        """Step 5: Remove e or l"""
        r1_start, r2_start, r1, r2 = self.find_r1_r2(word)

        # Step 5a: Remove e
        if word.endswith("e"):
            if (r2.endswith("e") or
                (r1.endswith("e") and not self.cvc_pattern(word[:-1]))):
                return word[:-1]

        # Step 5b: Remove l
        if (word.endswith("l") and r2.endswith("l") and
            len(word) > 1 and word[-2].lower() == 'l'):
            return word[:-1]

        return word

    def stem(self, word):
        """Apply the complete Porter2 stemming algorithm"""
        if len(word) <= 2:
            return word

        # Convert to lowercase for processing but preserve original case pattern
        original = word
        word = word.lower()

        # Mark initial y as consonant by converting to Y
        if word.startswith('y'):
            word = 'Y' + word[1:]

        # Mark y as consonant when preceded by vowel
        new_word = ""
        for i, char in enumerate(word):
            if char == 'y' and i > 0 and self.is_vowel(word, i - 1):
                new_word += 'Y'
            else:
                new_word += char
        word = new_word

        # Apply stemming steps
        word = self.step0(word)
        word = self.step1a(word)
        word = self.step1b(word)
        word = self.step1c(word)
        word = self.step2(word)
        word = self.step3(word)
        word = self.step4(word)
        word = self.step5(word)

        # Convert Y back to y
        word = word.replace('Y', 'y')

        return word

# %% [markdown]
# ## text_stemmer(text)

# %%
stemmer = Porter2Stemmer()

def text_stemmer(text):
    text = text if isinstance(text, str) else str(text)

    words = Text_Processing(text).split()

    # If it's a single word, stem and return it
    if len(words) == 1:
        return stemmer.stem(words[0])

    # If it's a sentence, stem each word
    stemmed_words = [stemmer.stem(word) for word in words]
    return " ".join(stemmed_words)

# %% [markdown]
# ## build_vocabulary(dataset)

# %%
import pickle
from collections import Counter

from collections import Counter

def build_vocabulary(dataset):
    word_counter = Counter()
    for sentence in dataset:
        words = Text_Processing(sentence).split()
        word_counter.update(words)

    sorted_words = sorted(word_counter.items(), key=lambda x: x[1])

    vocab = {word: idx for idx, (word, _) in enumerate(sorted_words)}

    return vocab

def stabilize_vocab_stemming(vocab, stemmer):
    prev_length = -1
    while prev_length != len(vocab):
        prev_length = len(vocab)
        vocab = [stemmer.stem(word) for word in vocab]
        vocab = list(dict.fromkeys(vocab))  # remove duplicates
    return vocab


def save_vocabulary(vocab, filename):
    with open(filename, 'wb') as file:
        pickle.dump(vocab, file)
        
def load_vocabulary(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)

# %% [markdown]
# ## remove unwanted samples

# %%
from collections import Counter
import re

def remove_samples_with_uncommon_chars(df, col_list=['question1', 'question2']):
    allowed_pattern = re.compile(r'^[a-zA-Z0-9\s!"#$%&\'()*+,\-./:;<=>?@\\^_`{|}~]*$')
    def is_clean(text):
        text = str(text)  # Ensure it's a string
        return bool(allowed_pattern.fullmatch(text))
    mask = df[col_list].map(is_clean).all(axis=1)
    return df[mask].reset_index(drop=True)

def remove_short_samples(df, col_list=['question1', 'question2'], min_words=6):
    def word_count(text):
        return len(str(text).split())
    mask = df[col_list].map(word_count).gt(min_words - 1).all(axis=1)
    return df[mask].reset_index(drop=True)

def remove_rare_word_samples(df, col_list=['question1', 'question2'], min_freq=5):
    all_words = []
    for col in col_list:
        all_words.extend(' '.join(df[col].astype(str)).split())
    word_freq = Counter(all_words)
    def has_only_frequent_words(text):
        words = str(text).split()
        return all(word_freq[word] >= min_freq for word in words)
    mask = df[col_list].map(has_only_frequent_words).all(axis=1)
    return df[mask].reset_index(drop=True)

# %%
import pandas as pd

dataset = pd.read_csv('semantic_web.csv')
print(f"Total Samples = {len(dataset)}")

print("Removing samples with uncommon character...")
uncommon = remove_samples_with_uncommon_chars(dataset)
print(f"New Total Samples = {len(uncommon)}")

print("Removing samples with words number less than 10...")
short_samples = remove_short_samples(uncommon, min_words = 10)
print(f"New Total Samples = {len(short_samples)}")

print("Removing samples with words that has low frequency < 50...")
rare_words = remove_rare_word_samples(short_samples, min_freq=50)
print(f"Final Total Samples = {len(rare_words)}")

print("Saving the processed_dataset...")
questions1 = rare_words['question1']
questions2 = rare_words['question2']
is_duplicate = rare_words['is_duplicate']
new_dataset = pd.DataFrame({
    'question1': questions1,
    'question2': questions2,
    'is_duplicate': is_duplicate
})
new_dataset.to_csv("processed_dataset.csv", index=False)
print("==Save Completed!==")
# Out:
# Total Samples = 404288
# Removing samples with uncommon character...
# New Total Samples = 394624
# Removing samples with words number less than 10...
# New Total Samples = 139441
# Removing samples with words that has low frequency < 50...
# Final Total Samples = 16330
# Saving the processed_dataset...
# ==Save Completed!==

# %% [markdown]
# ## BOW

# %%
def bag_of_words_vectorizer(vocabulary, sentence):

    sentence = Text_Processing(sentence)
    sentence = stemmer.stem(sentence)
    words = sentence.split()
    
    # Initialize binary BoW vector
    bow_vector = [0] * len(vocabulary)

    # Set 1 if the word exists in the sentence
    for idx, word in enumerate(vocabulary):
        bow_vector[idx] = 1 if word in words else 0

    return bow_vector

# %% [markdown]
# ## TF-IDF -> Term Frequency - Inverse Document Frequency

# %%
import math
import numpy as np

def compute_idf(documents, vocab_set):
    N = len(documents)
    df = {}

    for doc in documents:
        words = set(doc.split())
        for word in words:
            if word in vocab_set:
                df[word] = df.get(word, 0) + 1

    idf = {}
    for word in vocab_set:
        count = df.get(word, 0)
        idf[word] = math.log((N + 1) / (count + 1)) + 1 

    return idf


def tf_idf_vectorizer(text, vocab_set, idf_dict):
    words = set(text.split())
    tfidf = {}

    for word in words:
        if word in vocab_set:
            tfidf[word] = 1 * idf_dict[word]

    return tfidf

def merge_sparse(v1, v2):
    merged = v1.copy()
    for k, v in v2.items():
        merged[k + "_2"] = v
    return merged

def sparse_to_dense(x, feature_list):
    arr = np.zeros(len(feature_list))
    for i, feat in enumerate(feature_list):
        if feat in x:
            arr[i] = x[feat]
    return arr

def save_idf(idf, filename):
    with open(filename, 'wb') as file:
        pickle.dump(idf, file)
        
def load_idf(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)

# %% [markdown]
# ## Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

class LogisticRegression:
    def __init__(self, lr=0.1, epochs=100):
        self.initial_lr = lr
        self.lr = lr
        self.epochs = epochs
        self.weights = None
        self.bias = 0.0
        self.train_losses = []
        self.val_losses = []
        self.train_accuracies = []
        self.val_accuracies = []

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def _loss(self, y_true, y_pred):
        y_pred = np.clip(y_pred, 1e-10, 1 - 1e-10)
        return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

    def fit(self, X, y, X_val=None, y_val=None):
        X = np.array(X)
        y = np.array(y)
        if X_val is not None:
            X_val = np.array(X_val)
            y_val = np.array(y_val)
            
        n_samples, n_features = X.shape
        self.weights = np.random.uniform(-0.01, 0.01, size=n_features)
        self.bias = 0.0
        prev_acc = 0

        for epoch in range(1, self.epochs + 1):
            for i in range(n_samples):
                xi = X[i]
                yi = y[i]
                z = np.dot(self.weights, xi) + self.bias
                y_hat = self._sigmoid(z)
                error = y_hat - yi
                self.weights -= self.lr * error * xi
                self.bias -= self.lr * error

            # Evaluation
            y_train_pred = self._sigmoid(np.dot(X, self.weights) + self.bias)
            train_loss = self._loss(y, y_train_pred)
            train_acc = self.evaluate(X, y)
            self.train_losses.append(train_loss)
            self.train_accuracies.append(train_acc)
            
            if X_val is not None:
                y_val_pred = self._sigmoid(np.dot(X_val, self.weights) + self.bias)
                val_loss = self._loss(y_val, y_val_pred)
                val_acc = self.evaluate(X_val, y_val)
                self.val_losses.append(val_loss)
                self.val_accuracies.append(val_acc)

            if epoch % 10 == 0:
                print(f"Epoch {epoch}:")
                print(f"  Train Accuracy: {train_acc:.4f}, Loss: {train_loss:.4f}")
                if X_val is not None:
                    print(f"  Val   Accuracy: {val_acc:.4f}, Loss: {val_loss:.4f}")
                    
                if train_acc - prev_acc < 0 and train_acc > 0.85 and self.lr > self.initial_lr / 10:
                    self.lr /= 10
                    print(f"  Accuracy decreased, learning rate reduced to {self.lr:.5f}")
                    
                if train_acc >= 0.95 and train_acc < prev_acc:
                    print("  Accuracy dropped after reaching 95% — stopping early.")
                    break
            prev_acc = train_acc

    def predict_proba(self, X):
        X = np.array(X)
        z = np.dot(X, self.weights) + self.bias
        return self._sigmoid(z)

    def predict(self, X):
        proba = self.predict_proba(X)
        return (proba >= 0.5).astype(int)

    def evaluate(self, X, y):
        X = np.array(X)
        y = np.array(y)
        preds = self.predict(X)
        return np.mean(preds == y)

    def plot_metrics(self):
        epochs = range(1, len(self.train_losses) + 1)

        plt.figure(figsize=(12, 5))

        # Loss plot
        plt.subplot(1, 2, 1)
        plt.plot(epochs, self.train_losses, label='Train Loss')
        if self.val_losses:
            plt.plot(epochs, self.val_losses, label='Val Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Loss over Time')
        plt.legend()

        # Accuracy plot
        plt.subplot(1, 2, 2)
        plt.plot(epochs, self.train_accuracies, label='Train Accuracy')
        if self.val_accuracies:
            plt.plot(epochs, self.val_accuracies, label='Val Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Accuracy over Time')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def save(self, path):
        with open(path, 'wb') as f:
            pickle.dump({
                'weights': self.weights,
                'bias': self.bias,
                'lr': self.lr,
                'train_losses': self.train_losses,
                'val_losses': self.val_losses,
                'train_accuracies': self.train_accuracies,
                'val_accuracies': self.val_accuracies
            }, f)

    def load(self, path):
        with open(path, 'rb') as f:
            data = pickle.load(f)
            self.weights = data['weights']
            self.bias = data['bias']
            self.lr = data['lr']
            self.train_losses = data.get('train_losses', [])
            self.val_losses = data.get('val_losses', [])
            self.train_accuracies = data.get('train_accuracies', [])
            self.val_accuracies = data.get('val_accuracies', [])

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
import random
import numpy as np
import pickle
import matplotlib.pyplot as plt

class SVMClassifier:
    def __init__(self, lr=0.001, epochs=1000, C=1.0):
        self.lr = lr
        self.epochs = epochs
        self.C = C
        self.w = {}    # Sparse weights
        self.b = 0
        self.prev_acc = -1
        self.train_losses = []
        self.val_losses = []
        self.train_accuracies = []
        self.val_accuracies = []

    def _dot(self, x):
        return sum(self.w.get(k, 0.0) * v for k, v in x.items())

    def _hinge_loss(self, x, y):
        score = self._dot(x) + self.b
        return max(0, 1 - y * score)

    def _update(self, x, y):
        score = self._dot(x) + self.b
        if y * score >= 1:
            for k in x:
                self.w[k] = self.w.get(k, 0.0) - self.lr * self.w.get(k, 0.0)
        else:
            for k, v in x.items():
                self.w[k] = self.w.get(k, 0.0) + self.lr * (self.C * y * v - self.w.get(k, 0.0))
            self.b += self.lr * self.C * y

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y, X_val=None, y_val=None):
        y = [1 if label == 1 else -1 for label in y]

        for epoch in range(self.epochs):
            combined = list(zip(X, y))
            random.shuffle(combined)

            total_loss = 0
            correct = 0

            for x_i, y_i in combined:
                self._update(x_i, y_i)
                loss = self._hinge_loss(x_i, y_i)
                total_loss += loss
                pred = 1 if (self._dot(x_i) + self.b) >= 0 else -1
                correct += (pred == y_i)

            # Store training metrics
            self.train_losses.append(total_loss / len(X))
            self.train_accuracies.append(correct / len(X))
                
            if epoch % 10 == 0:
                print(f"Epoch {epoch}:")
                train_acc = correct / len(X)
                train_loss = total_loss / len(X)
                print(f"  Train Accuracy: {train_acc:.4f}, Loss: {train_loss:.4f}")
            self.prev_acc = train_acc

    def predict_proba(self, X):
        z = np.array([self._dot(x) + self.b for x in X])
        return self._sigmoid(z)

    def predict(self, X):
        return [1 if self._dot(x) + self.b >= 0 else 0 for x in X]

    def evaluate(self, X, y):
        preds = self.predict(X)
        return np.mean([p == t for p, t in zip(preds, y)])

    def _evaluate_internal(self, X, y):
        y_bin = [1 if label == 1 else -1 for label in y]
        total_loss = 0
        correct = 0

        for x_i, y_i in zip(X, y_bin):
            total_loss += self._hinge_loss(x_i, y_i)
            pred = 1 if (self._dot(x_i) + self.b) >= 0 else -1
            correct += (pred == y_i)

        return total_loss / len(X), correct / len(X)

    def plot_metrics(self):
        epochs = range(1, len(self.train_losses) + 1)

        plt.figure(figsize=(12, 5))

        # Loss plot
        plt.subplot(1, 2, 1)
        plt.plot(epochs, self.train_losses, label='Train Loss')
        if self.val_losses:
            plt.plot(epochs, self.val_losses, label='Val Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Loss over Time')
        plt.legend()

        # Accuracy plot
        plt.subplot(1, 2, 2)
        plt.plot(epochs, self.train_accuracies, label='Train Accuracy')
        if self.val_accuracies:
            plt.plot(epochs, self.val_accuracies, label='Val Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Accuracy over Time')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def save(self, path):
        with open(path, 'wb') as f:
            pickle.dump({
                'weights': self.w,
                'bias': self.b,
                'lr': self.lr,
                'train_losses': self.train_losses,
                'val_losses': self.val_losses,
                'train_accuracies': self.train_accuracies,
                'val_accuracies': self.val_accuracies
            }, f)

    def load(self, path):
        with open(path, 'rb') as f:
            data = pickle.load(f)
            self.w = data['weights']
            self.b = data['bias']
            self.lr = data['lr']
            self.train_losses = data.get('train_losses', [])
            self.val_losses = data.get('val_losses', [])
            self.train_accuracies = data.get('train_accuracies', [])
            self.val_accuracies = data.get('val_accuracies', [])

# %% [markdown]
# # Main Code

# %%
dataset = pd.read_csv('processed_dataset.csv')
print(f"dataset samples = {len(dataset)}")

dataset['question1'] = dataset['question1'].apply(Text_Processing)
dataset['question2'] = dataset['question2'].apply(Text_Processing)

combined_dataset = list(dataset['question1']) + list(dataset['question2'])

vocabulary = build_vocabulary(combined_dataset)
print(f"vocabulary number before stemming = {len(vocabulary)}")

vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
print(f"vocabulary number after stemming = {len(vocabulary)}")
# Out:
# dataset samples = 16330
# vocabulary number before stemming = 3802
# vocabulary number after stemming = 3802

# %% [markdown]
# # BOW + Logistic Training

# %%
import random

sample_size = 5000

data_q1 = dataset['question1'][:sample_size]
data_q2 = dataset['question2'][:sample_size]
labels = dataset['is_duplicate'][:sample_size]

combined_dataset = list(data_q1) + list(data_q2)

vocabulary = build_vocabulary(combined_dataset)
print(f"vocabulary number before stemming = {len(vocabulary)}")

vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
print(f"vocabulary number after stemming = {len(vocabulary)}")

save_vocabulary(vocabulary, "BOW_Vocab.pkl")

X = []
for q1, q2 in zip(data_q1, data_q2):
    v1 = bag_of_words_vectorizer(vocabulary, str(q1))
    v2 = bag_of_words_vectorizer(vocabulary, str(q2))
    X.append(v1 + v2)

samples = list(zip(X, labels))
random.shuffle(samples)
split_idx = int(0.8 * len(samples))
train_data = samples[:split_idx]
test_data = samples[split_idx:]

X_train, y_train = zip(*train_data)
X_test, y_test = zip(*test_data)

model = LogisticRegression(lr=0.1, epochs=100)
model.fit(X_train, y_train, X_test, y_test)

# Save
model.save("BOW_logistic_model.pkl")

# Plot
model.plot_metrics()
# Out:
# vocabulary number before stemming = 3092
# vocabulary number after stemming = 3092
# Epoch 10:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# Epoch 20:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# Epoch 30:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# Epoch 40:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# Epoch 50:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# Epoch 60:
#   Train Accuracy: 0.6085, Loss: 0.6695
#   Val   Accuracy: 0.6020, Loss: 0.6725
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 35
#      32 X_test, y_test = zip(*test_data)
#      34 model = LogisticRegression(lr=0.1, epochs=100)
# ---> 35 model.fit(X_train, y_train, X_test, y_test)
#      37 # Save
# ...

# %% [markdown]
# # TF-IDF + Logistic Training

# %%
import random
import numpy as np

# Prepare data as before
sample_size = 5000
data_q1 = dataset['question1'][:sample_size]
data_q2 = dataset['question2'][:sample_size]
labels = list(dataset['is_duplicate'][:sample_size])

combined_dataset = list(data_q1) + list(data_q2)

vocabulary = build_vocabulary(combined_dataset)
print(f"Vocabulary number before stemming = {len(vocabulary)}")

vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
print(f"Vocabulary number after stemming = {len(vocabulary)}")

idf = compute_idf(combined_dataset, vocabulary)

# Compute sparse TF-IDF vectors for question pairs
X_sparse = [(tf_idf_vectorizer(str(q1), vocabulary, idf), tf_idf_vectorizer(str(q2), vocabulary, idf)) for q1, q2 in zip(data_q1, data_q2)]
X_merged_sparse = [merge_sparse(q1, q2) for q1, q2 in X_sparse]

# Build fixed feature list from all keys (like vocabulary but extended with "_2" keys)
all_features = set()
for x in X_merged_sparse:
    all_features.update(x.keys())
all_features = sorted(all_features)

save_vocabulary(vocabulary, "tf_idf_vocabulary.pkl")

save_idf(idf, "idf.pkl")

# Convert sparse dicts to dense numpy arrays
def sparse_to_dense(x, feature_list):
    arr = np.zeros(len(feature_list))
    for i, feat in enumerate(feature_list):
        if feat in x:
            arr[i] = x[feat]
    return arr

X_dense = [sparse_to_dense(x, all_features) for x in X_merged_sparse]

# Shuffle and split
samples = list(zip(X_dense, labels))
random.shuffle(samples)

split_idx = int(0.8 * len(samples))
X_train, y_train = zip(*samples[:split_idx])
X_test, y_test = zip(*samples[split_idx:])

# Convert to numpy arrays (optional but often easier for logistic regression)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)


model = LogisticRegression(lr=0.1, epochs=1000)
model.fit(X_train, y_train, X_test, y_test)

# Save
model.save("TF_IDF_logistic_model.pkl")

# Load
model2 = LogisticRegression()
model2.load("TF_IDF_logistic_model.pkl")

# Plot
model.plot_metrics()
# Out:
# Vocabulary number before stemming = 3092
# Vocabulary number after stemming = 3092
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 21
#      18 idf = compute_idf(combined_dataset, vocabulary)
#      20 # Compute sparse TF-IDF vectors for question pairs
# ---> 21 X_sparse = [(tf_idf_vectorizer(str(q1), vocabulary, idf), tf_idf_vectorizer(str(q2), vocabulary, idf)) for q1, q2 in zip(data_q1, data_q2)]
#      22 X_merged_sparse = [merge_sparse(q1, q2) for q1, q2 in X_sparse]
#      24 # Build fixed feature list from all keys (like vocabulary but extended with "_2" keys)
#
# Cell In[52], line 27, in tf_idf_vectorizer(text, vocab_set, idf_dict)
#      24 tfidf = {}
#      26 for word in words:
# ---> 27     if word in vocab_set:
#      28         tfidf[word] = 1 * idf_dict[word]
#      30 return tfidf
#
# KeyboardInterrupt:

# %%
import random
import numpy as np

# Your preprocessing functions and TF-IDF functions already exist

def merge_sparse(v1, v2):
    merged = v1.copy()
    for k, v in v2.items():
        merged[k + "_2"] = v
    return merged

# Prepare data as before
sample_size = 5000
data_q1 = dataset['question1'][:sample_size]
data_q2 = dataset['question2'][:sample_size]
labels = list(dataset['is_duplicate'][:sample_size])

combined_dataset = list(data_q1) + list(data_q2)

vocabulary = build_vocabulary(combined_dataset)
print(f"Vocabulary number before stemming = {len(vocabulary)}")

vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
print(f"Vocabulary number after stemming = {len(vocabulary)}")

idf = compute_idf(combined_dataset, vocabulary)

# Compute sparse TF-IDF vectors for question pairs
X_sparse = [(tf_idf_vectorizer(str(q1), vocabulary, idf), tf_idf_vectorizer(str(q2), vocabulary, idf)) for q1, q2 in zip(data_q1, data_q2)]
X_merged_sparse = [merge_sparse(q1, q2) for q1, q2 in X_sparse]

# Build fixed feature list from all keys (like vocabulary but extended with "_2" keys)
all_features = set()
for x in X_merged_sparse:
    all_features.update(x.keys())
all_features = sorted(all_features)

# Convert sparse dicts to dense numpy arrays
def sparse_to_dense(x, feature_list):
    arr = np.zeros(len(feature_list))
    for i, feat in enumerate(feature_list):
        if feat in x:
            arr[i] = x[feat]
    return arr

X_dense = [sparse_to_dense(x, all_features) for x in X_merged_sparse]

# Shuffle and split
samples = list(zip(X_dense, labels))
random.shuffle(samples)

split_idx = int(0.8 * len(samples))
X_train, y_train = zip(*samples[:split_idx])
X_test, y_test = zip(*samples[split_idx:])

# Convert to numpy arrays (optional but often easier for logistic regression)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

model = LogisticRegression(lr=0.01, epochs=100)
model.fit(X_train, y_train, X_test, y_test)

# Save
model.save("TF_IDF_logistic_model_lowlr.pkl")

# Load
model2 = LogisticRegression()
model2.load("TF_IDF_logistic_model_lowlr.pkl")

# Plot
model.plot_metrics()
# Out:
# Vocabulary number before stemming = 3092
# Vocabulary number after stemming = 3092
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 26
#      23 vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
#      24 print(f"Vocabulary number after stemming = {len(vocabulary)}")
# ---> 26 idf = compute_idf(combined_dataset, vocabulary)
#      28 # Compute sparse TF-IDF vectors for question pairs
#      29 X_sparse = [(tf_idf_vectorizer(str(q1), vocabulary, idf), tf_idf_vectorizer(str(q2), vocabulary, idf)) for q1, q2 in zip(data_q1, data_q2)]
#
# Cell In[16], line 9, in compute_idf(documents, vocab_set)
#       7 for doc in documents:
#       8     words = set(doc.split())
# ----> 9     for word in words:
#      10         if word in vocab_set:
#      11             df[word] = df.get(word, 0) + 1
#
# KeyboardInterrupt:

# %% [markdown]
# # TF-IDF + SVM

# %%
import random

sample_size = 5000
data_q1 = dataset['question1'][:sample_size]
data_q2 = dataset['question2'][:sample_size]
labels = dataset['is_duplicate'][:sample_size]

combined_dataset = list(data_q1) + list(data_q2)

vocabulary = build_vocabulary(combined_dataset)
print(f"vocabulary number before stemming = {len(vocabulary)}")

vocabulary = stabilize_vocab_stemming(vocabulary, stemmer)
print(f"vocabulary number after stemming = {len(vocabulary)}")

idf = compute_idf(combined_dataset, vocabulary)

# Preprocess input (merge TF-IDF dicts)
def merge_sparse(v1, v2):
    merged = v1.copy()
    for k, v in v2.items():
        merged[k + "_2"] = v 
    return merged

X = [(tf_idf_vectorizer(str(q1), vocabulary, idf),tf_idf_vectorizer(str(q2), vocabulary, idf)) for q1, q2 in zip(data_q1, data_q2)]
X_merged = [merge_sparse(q1, q2) for q1, q2 in X]

# Shuffle + split
samples = list(zip(X_merged, labels))
random.shuffle(samples)
split = int(0.8 * len(samples))
X_train, y_train = zip(*samples[:split])
X_test, y_test = zip(*samples[split:])

# ✅ Same API as LogisticRegression
model = SVMClassifier(lr=0.001, epochs=1000, C=2.5)
model.fit(list(X_merged), list(labels))

# Predictions
proba = model.predict_proba(X_test)
preds = model.predict(X_test)

# Evaluation
print("Test Accuracy:", model.evaluate(X_test, y_test))

# Plot metrics
model.plot_metrics()

# Save / Load
model.save("svm_model.pkl")
model.load("svm_model.pkl")
# Out:
# vocabulary number before stemming = 3092
# vocabulary number after stemming = 2499
# Epoch 0:
#   Train Accuracy: 0.8734, Loss: 0.3351
# Epoch 10:
#   Train Accuracy: 0.9296, Loss: 0.1672
# Epoch 20:
#   Train Accuracy: 0.9338, Loss: 0.1478
# Epoch 30:
#   Train Accuracy: 0.9392, Loss: 0.1392
# Epoch 40:
#   Train Accuracy: 0.9442, Loss: 0.1336
# Epoch 50:
#   Train Accuracy: 0.9418, Loss: 0.1302
# Epoch 60:
#   Train Accuracy: 0.9432, Loss: 0.1273
# Epoch 70:
#   Train Accuracy: 0.9472, Loss: 0.1222
# Epoch 80:
#   Train Accuracy: 0.9472, Loss: 0.1224
# Epoch 90:
#   Train Accuracy: 0.9484, Loss: 0.1226
# Epoch 100:
#   Train Accuracy: 0.9494, Loss: 0.1221
# Epoch 110:
#   Train Accuracy: 0.9490, Loss: 0.1187
# Epoch 120:
#   Train Accuracy: 0.9502, Loss: 0.1183
# Epoch 130:
#   Train Accuracy: 0.9490, Loss: 0.1203
# Epoch 140:
#   Train Accuracy: 0.9490, Loss: 0.1166
# Epoch 150:
#   Train Accuracy: 0.9508, Loss: 0.1188
# Epoch 160:
#   Train Accuracy: 0.9512, Loss: 0.1165
# ...

# %% [markdown]
# # end of tf-idf

# %%
def BOW_Logistic(quest1, quest2):
    model = LogisticRegression()
    model.load("BOW_logistic_model.pkl")
    vocab = load_vocabulary("BOW_Vocab.pkl")
    v1 = bag_of_words_vectorizer(vocabulary, str(quest1))
    v2 = bag_of_words_vectorizer(vocabulary, str(quest2))
    x = v1 + v2
    result = model.predict(x)
    return result

# %%
def TF_IDF_Logistic(quest1, quest2):
    model = LogisticRegression()
    model.load("TF_IDF_logistic_model.pkl")
    vocab = load_vocabulary("tf_idf_vocabulary.pkl")
    idf = load_idf("idf.pkl")
    v1 = tf_idf_vectorizer(str(quest1), vocab, idf)
    v2 = tf_idf_vectorizer(str(quest2), vocab, idf)
    x_merge = merge_sparse(v1, v2)
    x_dens = sparse_to_dense(x_merge, all_features)
    result = model.predict(x_dens)
    return result

# %%
def TF_IDF_SVM(quest1, quest2):
    model = LogisticRegression()
    model.load("svm_model.pkl.pkl")
    vocab = load_vocabulary("tf_idf_vocabulary.pkl")
    idf = load_idf("idf.pkl")
    v1 = tf_idf_vectorizer(str(quest1), vocab, idf)
    v2 = tf_idf_vectorizer(str(quest2), vocab, idf)
    x_merge = merge_sparse(v1, v2)
    x_dens = sparse_to_dense(x_merge, all_features)
    result = model.predict(x_dens)
    return result
